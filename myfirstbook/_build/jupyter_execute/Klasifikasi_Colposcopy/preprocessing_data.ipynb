# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
from sktime.datasets import load_from_tsfile_to_dataframe
from sklearn.model_selection import StratifiedKFold
from sktime.transformations.panel.rocket import MiniRocket

# %% [markdown]
# ## Path

# %%
TRAIN_DIR = r"D:\KULIAH\SEMESTER 5\Program Saint Data\Uranus\myfirstbook\Klasifikasi_Colposcopy\Dataset\Colposcopy_TRAIN.ts"
TEST_DIR = r"D:\KULIAH\SEMESTER 5\Program Saint Data\Uranus\myfirstbook\Klasifikasi_Colposcopy\Dataset\Colposcopy_TEST.ts"

X_train, y_train = load_from_tsfile_to_dataframe(TRAIN_DIR)
X_test,  y_test  = load_from_tsfile_to_dataframe(TEST_DIR)

print("Train path :", TRAIN_DIR)
print("Val path   :", TEST_DIR)
# Out:
# Train path : D:\KULIAH\SEMESTER 5\Program Saint Data\Uranus\myfirstbook\Klasifikasi_Colposcopy\Dataset\Colposcopy_TRAIN.ts
# Val path   : D:\KULIAH\SEMESTER 5\Program Saint Data\Uranus\myfirstbook\Klasifikasi_Colposcopy\Dataset\Colposcopy_TEST.ts

# %% [markdown]
# ## Gabungkan Data

# %%
X_all = np.vstack((X_train, X_test))   

y_all = np.concatenate((y_train, y_test))  

print("X_all shape:", X_all.shape)
print("y_all shape:", y_all.shape)
print("Distribusi kelas:", np.unique(y_all, return_counts=True))
# Out:
# X_all shape: (200, 1)
# y_all shape: (200,)
# Distribusi kelas: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([15, 24, 20, 48, 37, 56], dtype=int64))

# %%
X_all_arr = np.vstack(X_all[:, 0])

print("X_all_arr shape:", X_all_arr.shape)
print("Contoh 1 baris:", X_all_arr[0][:10])
# Out:
# X_all_arr shape: (200, 180)
# Contoh 1 baris: [4.49790795 4.49790795 7.79288703 2.14435146 0.73221757 5.91004184
#  2.14435146 0.73221757 0.73221757 2.14435146]

# %% [markdown]
# ## Normalisasi

# %%
def z_normalize_ts(X):
    """
    Z-normalization per time series
    X shape: (n_samples, n_timesteps)
    """
    X_norm = np.zeros_like(X, dtype=float)
    
    for i in range(X.shape[0]):
        mean = X[i].mean()
        std = X[i].std()
        if std == 0:
            X_norm[i] = X[i] 
        else:
            X_norm[i] = (X[i] - mean) / std
    
    return X_norm

X_norm = z_normalize_ts(X_all_arr)

print("X_norm shape:", X_norm.shape)
print("Mean sample 0:", X_norm[0].mean())
print("Std sample 0:", X_norm[0].std())
# Out:
# X_norm shape: (200, 180)
# Mean sample 0: 4.194175870806147e-17
# Std sample 0: 1.0

# %% [markdown]
# ## Stratified K-Fold

# %%
skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

for fold, (train_idx, val_idx) in enumerate(skf.split(X_norm, y_all), 1):
    print(f"\nFold {fold}")
    print("Train size:", len(train_idx))
    print("Val size:", len(val_idx))
    print("Distribusi kelas Train:", np.unique(y_all[train_idx], return_counts=True))
    print("Distribusi kelas Val:", np.unique(y_all[val_idx], return_counts=True))
# Out:
# Fold 1
# Train size: 160
# Val size: 40
# Distribusi kelas Train: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([12, 19, 16, 38, 30, 45], dtype=int64))
# Distribusi kelas Val: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([ 3,  5,  4, 10,  7, 11], dtype=int64))
#
# Fold 2
# Train size: 160
# Val size: 40
# Distribusi kelas Train: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([12, 19, 16, 38, 30, 45], dtype=int64))
# Distribusi kelas Val: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([ 3,  5,  4, 10,  7, 11], dtype=int64))
#
# Fold 3
# Train size: 160
# Val size: 40
# Distribusi kelas Train: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([12, 19, 16, 39, 29, 45], dtype=int64))
# Distribusi kelas Val: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([ 3,  5,  4,  9,  8, 11], dtype=int64))
#
# Fold 4
# Train size: 160
# Val size: 40
# Distribusi kelas Train: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([12, 19, 16, 39, 29, 45], dtype=int64))
# Distribusi kelas Val: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([ 3,  5,  4,  9,  8, 11], dtype=int64))
#
# Fold 5
# Train size: 160
# Val size: 40
# Distribusi kelas Train: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([12, 20, 16, 38, 30, 44], dtype=int64))
# Distribusi kelas Val: (array(['0', '1', '2', '3', '4', '5'], dtype='<U1'), array([ 3,  4,  4, 10,  7, 12], dtype=int64))

# %% [markdown]
# ## FIT MiniROCKET (FEATURE EXTRACTION)

# %%
train_idx, val_idx = next(skf.split(X_norm, y_all))

X_train = X_norm[train_idx]
X_val   = X_norm[val_idx]
y_train = y_all[train_idx]
y_val   = y_all[val_idx]

rocket = MiniRocket(
    num_kernels=1000,
    random_state=42
)

rocket.fit(X_train)

X_train_rocket = rocket.transform(X_train)
X_val_rocket   = rocket.transform(X_val)

print("X_train_rocket shape:", X_train_rocket.shape)
print("X_val_rocket shape:", X_val_rocket.shape)
# Out:
# -------------------------------------------------------------------------
# AssertionError                          Traceback (most recent call last)
# AssertionError: Sizes of $278binary_subscr.10, $288binary_subscr.16 do not match on c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\transformations\panel\rocket\_minirocket_numba.py (710)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                             Traceback (most recent call last)
# Cell In[7], line 16
#      13 rocket.fit(X_train)
#      15 X_train_rocket = rocket.transform(X_train)
# ---> 16 X_val_rocket   = rocket.transform(X_val)
#      18 print("X_train_rocket shape:", X_train_rocket.shape)
#      19 print("X_val_rocket shape:", X_val_rocket.shape)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\transformations\base.py:575, in BaseTransformer.transform(self, X, y)
#     572     Xt = self._transform(X=X_inner, y=y_inner)
#     573 else:
#     574     # otherwise we call the vectorized version of predict
# --> 575     Xt = self._vectorize("transform", X=X_inner, y=y_inner)
#     577 # obtain configs to control input and output control
#     578 configs = self.get_config()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\transformations\base.py:1348, in BaseTransformer._vectorize(self, methodname, **kwargs)
#    1339     transformers_ = X.vectorize_est(
#    1340         transformers_,
#    1341         method="fit",
#    (...)
#    1344         **kwargs,
#    1345     )
#    1347 # transform the i-th series/panel with the i-th stored transformer
# -> 1348 Xts = X.vectorize_est(
#    1349     transformers_,
#    1350     method=methodname,
#    1351     return_type="list",
#    1352     backend=self.get_config()["backend:parallel"],
#    1353     backend_params=self.get_config()["backend:parallel:params"],
#    1354     **kwargs,
#    1355 )
#    1356 Xt = X.reconstruct(Xts, overwrite_index=False)
#    1358 return Xt
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\datatypes\_vectorize.py:630, in VectorizedDF.vectorize_est(self, estimator, method, args, args_rowvec, return_type, rowname_default, colname_default, varname_of_self, backend, backend_params, **kwargs)
#     616 vec_zip = zip(
#     617     self.items(),
#     618     explode(args, iterate_as=iterate_as, iterate_cols=iterate_cols),
#     619     explode(args_rowvec, iterate_as=iterate_as, iterate_cols=False),
#     620     estimators,
#     621 )
#     623 meta = {
#     624     "method": method,
#     625     "varname_of_self": varname_of_self,
#     626     "rowname_default": rowname_default,
#     627     "colname_default": colname_default,
#     628 }
# --> 630 ret = parallelize(
#     631     fun=self._vectorize_est_single,
#     632     iter=vec_zip,
#     633     meta=meta,
#     634     backend=backend,
#     635     backend_params=backend_params,
#     636 )
#     638 if return_type == "pd.DataFrame":
#     639     df_long = pd.DataFrame(ret)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\utils\parallel.py:72, in parallelize(fun, iter, meta, backend, backend_params)
#      69 backend_name = backend_dict[backend]
#      70 para_fun = para_dict[backend_name]
# ---> 72 ret = para_fun(
#      73     fun=fun, iter=iter, meta=meta, backend=backend, backend_params=backend_params
#      74 )
#      75 return ret
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\utils\parallel.py:92, in _parallelize_none(fun, iter, meta, backend, backend_params)
#      90 def _parallelize_none(fun, iter, meta, backend, backend_params):
#      91     """Execute loop via simple sequential list comprehension."""
# ---> 92     ret = [fun(x, meta=meta) for x in iter]
#      93     return ret
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\utils\parallel.py:92, in <listcomp>(.0)
#      90 def _parallelize_none(fun, iter, meta, backend, backend_params):
#      91     """Execute loop via simple sequential list comprehension."""
# ---> 92     ret = [fun(x, meta=meta) for x in iter]
#      93     return ret
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\datatypes\_vectorize.py:679, in VectorizedDF._vectorize_est_single(self, vec_tuple, meta)
#     676     args_i[varname_of_self] = group
#     678 est_i_method = getattr(est_i, method)
# --> 679 est_i_result = est_i_method(**args_i)
#     681 if group_name is None:
#     682     group_name = rowname_default
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\transformations\base.py:572, in BaseTransformer.transform(self, X, y)
#     569 X_inner, y_inner, metadata = self._check_X_y(X=X, y=y, return_metadata=True)
#     571 if not isinstance(X_inner, VectorizedDF):
# --> 572     Xt = self._transform(X=X_inner, y=y_inner)
#     573 else:
#     574     # otherwise we call the vectorized version of predict
#     575     Xt = self._vectorize("transform", X=X_inner, y=y_inner)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sktime\transformations\panel\rocket\_minirocket.py:157, in MiniRocket._transform(self, X, y)
#     155     n_jobs = self.n_jobs
#     156 set_num_threads(n_jobs)
# --> 157 X_ = _transform(X, self.parameters)
#     158 set_num_threads(prev_threads)
#     159 return pd.DataFrame(X_)
#
# SystemError: _PyEval_EvalFrameDefault returned a result with an exception set
